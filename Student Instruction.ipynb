# %% [markdown]
# ##Instruction for students

# %% [markdown]
# **Data** **Description**
#
# Data talk about the details of people who have got the disease as a hypothyroid or not. This data is collected from UCI machine learning website. And also in disease prediction we have to see that the people who dose not have a disease should not be conveyed that they have a disease.

# %% [markdown]
# Steps to follow for processing
#
# *   Read and parse the dataset.As the dataset is imbalanced you have to balance the dataset also.
# *   Do some of the EDA in data
# *   Preprocess the data
# *   Try differen ML models
# *   Derive conclusion form the procedure.
